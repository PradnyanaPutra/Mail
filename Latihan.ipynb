# %%
# Import library yang diperlukan
# Nama : I Komang Pradnyana Putra
# Nim  : 170010045
import argparse
import getpass
import imaplib
import poplib
import smtplib

# %%
IMAP_SERVER = 'outlook.office365.com'
IMAP_PORT = 993
POP_SERVER = 'outlook.office365.com'
POP_PORT = 995

def imap_mail(username):
    mailbox = imaplib.IMAP4_SSL(IMAP_SERVER, IMAP_PORT) 
    password = getpass.getpass(prompt='Masukkan password email anda : ') 
    mailbox.login(username, password)
    mailbox.select('Inbox')
    typ, data = mailbox.search(None, 'ALL')
    for num in data[0].split():
        typ, data = mailbox.fetch(num, '(RFC822)')
        print ('Message %s\n%s\n' % (num, data[0][1]))
        break
    mailbox.close()
    mailbox.logout()
    
def pop_mail(username):
    mailbox = poplib.POP3_SSL(POP_SERVER, POP_PORT) 
    mailbox.user(username)
    password = getpass.getpass(prompt='Masukkan password email anda : ') 
    mailbox.pass_(password) 
    num_messages = len(mailbox.list()[1])
    print ('Total emails: {}'.format(num_messages))
    mailbox.quit()

# %% [markdown]
# Buatlah sebuah fungsi yang dapat menggabungkan fungsionalitas fungsi `imap_mail()` dan `pop_mail()`

# %%
def mail(username, protocol, host, port):
        imap_mail("170010045@stikom-bali.ac.id")
        pop_mail("170010045@stikom-bali.ac.id")

# %% [markdown]
# Panggil fungsi `mail()` di bawah ini:

# %%
if __name__ == '__main__':
    mail("username","","","")
# Out:
# Masukkan password email anda : ········
# Message b'1'
# b'Received: from KL1PR0601MB1909.apcprd06.prod.outlook.com\r\n (2603:1096:202:2e::20) by HK0PR06MB2578.apcprd06.prod.outlook.com with HTTPS\r\n via HK2PR06CA0008.APCPRD06.PROD.OUTLOOK.COM; Fri, 20 Mar 2020 01:34:41 +0000\r\nARC-Seal: i=2; a=rsa-sha256; s=arcselector9901; d=microsoft.com; cv=pass;\r\n b=\r\nARC-Message-Signature: i=2; a=rsa-sha256; c=relaxed/relaxed; d=microsoft.com;\r\n s=arcselector9901;\r\n h=From:Date:Subject:Message-ID:Content-Type:MIME-Version:X-MS-Exchange-SenderADCheck;\r\n bh=xqMKEem9QmTOhRsSxzZXYhYPe2VoHbnqM9xoSmsbzpo=;\r\n b=\r\nARC-Authentication-Results: i=2; mx.microsoft.com 1; spf=pass (sender ip is\r\n 40.107.243.69) smtp.rcpttodomain=stikom-bali.ac.id\r\n smtp.mailfrom=email.teams.microsoft.com; dmarc=pass (p=reject sp=reject\r\n pct=100) action=none header.from=email.teams.microsoft.com; dkim=pass\r\n (signature was verified) header.d=email.teams.microsoft.com; arc=pass (0\r\n oda=1 ltdi=1 spf=[1,1,smtp.mailfrom=email.teams.microsoft.com]\r\n dmarc=[1,1,header.from=email.teams.microsoft.com])\r\nReceived: from SG2PR04CA0162.apcprd04.prod.outlook.com (2603:1096:4::24) by\r\n KL1PR0601MB1909.apcprd06.prod.outlook.com (2603:1096:802:8::21) with\r\n Microsoft SMTP Server (version=TLS1_2,\r\n cipher=TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384) id 15.20.2835.20; Fri, 20 Mar\r\n 2020 01:34:39 +0000\r\nReceived: from SG2APC01FT014.eop-APC01.prod.protection.outlook.com\r\n (2603:1096:4:0:cafe::84) by SG2PR04CA0162.outlook.office365.com\r\n (2603:1096:4::24) with Microsoft SMTP Server (version=TLS1_2,\r\n cipher=TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384) id 15.20.2835.19 via Frontend\r\n Transport; Fri, 20 Mar 2020 01:34:39 +0000\r\nAuthentication-Results: spf=pass (sender IP is 40.107.243.69)\r\n smtp.mailfrom=email.teams.microsoft.com; stikom-bali.ac.id; dkim=pass\r\n (signature was verified)\r\n header.d=email.teams.microsoft.com;stikom-bali.ac.id; dmarc=pass action=none\r\n header.from=email.teams.microsoft.com;compauth=pass reason=100\r\nReceived-SPF: Pass (protection.outlook.com: domain of\r\n email.teams.microsoft.com designates 40.107.243.69 as permitted sender)\r\n receiver=protection.outlook.com; client-ip=40.107.243.69;\r\n helo=NAM12-DM6-obe.outbound.protection.outlook.com;\r\nReceived: from NAM12-DM6-obe.outbound.protection.outlook.com (40.107.243.69)\r\n by SG2APC01FT014.mail.protection.outlook.com (10.152.250.188) with Microsoft\r\n SMTP Server (version=TLS1_2, cipher=TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384) id\r\n 15.20.2814.13 via Frontend Transport; Fri, 20 Mar 2020 01:34:38 +0000\r\nARC-Seal: i=1; a=rsa-sha256; s=arcselector9901; d=microsoft.com; cv=none;\r\n b=\r\nARC-Message-Signature: i=1; a=rsa-sha256; c=relaxed/relaxed; d=microsoft.com;\r\n s=arcselector9901;\r\n h=From:Date:Subject:Message-ID:Content-Type:MIME-Version:X-MS-Exchange-SenderADCheck;\r\n bh=xqMKEem9QmTOhRsSxzZXYhYPe2VoHbnqM9xoSmsbzpo=;\r\n b=Hv7Svb1QtV3i96dXjokoFpy94911O9DM7D6bwrbenNofaLcC0l/GUefUMHsztt3Ci5ukY4bJmZG ...
# Masukkan password email anda : ········
# Total emails: 8
